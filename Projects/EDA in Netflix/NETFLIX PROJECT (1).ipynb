# %% [markdown]
# ## NETFLIX SUBSCRIPTION FEE ANALYSIS

# %% [markdown]
# ## Introduction
# As we know Netflix is a popular application in the world were people can watch anything from anywhere at any time.Since it get more popular they started to pay for it,based on monthly or yearly.
# This subscription fee is divided into three: Basic, Standard and Premium.
#
# Here I am attempting to analyze the dataset on Netflix subscription fee.This set contains the fees based on different levels and the shows,movies that they provide in different countries are also presented.
# The first thing for analysis is importing the libraries like pandas,numpy and we use matplotlib and seaborn for visualize the dataset.

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Read the file and viewing it

# %%
data=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\Netflix subscription fee Dec-2021.csv')
data
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %% [markdown]
# ## Check how many rows and column

# %%
data.shape
# Out:
# (65, 8)

# %% [markdown]
# ## Print the field name

# %%
data.columns
# Out:
# Index(['Country_code', 'Country', 'Total Library Size', 'No. of TV Shows',
#        'No. of Movies', 'Cost Per Month - Basic ($)',
#        'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)'],
#       dtype='object')

# %% [markdown]
# ## Print the datatype

# %%
data.dtypes
# Out:
# Country_code                      object
# Country                           object
# Total Library Size                 int64
# No. of TV Shows                    int64
# No. of Movies                      int64
# Cost Per Month - Basic ($)       float64
# Cost Per Month - Standard ($)    float64
# Cost Per Month - Premium ($)     float64
# dtype: object

# %% [markdown]
# ## Print the missing values

# %%
data.isnull()
# Out:
#     Country_code  Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0          False    False               False            False          False
# 1          False    False               False            False          False
# 2          False    False               False            False          False
# 3          False    False               False            False          False
# 4          False    False               False            False          False
# ..           ...      ...                 ...              ...            ...
# 60         False    False               False            False          False
# 61         False    False               False            False          False
# 62         False    False               False            False          False
# 63         False    False               False            False          False
# 64         False    False               False            False          False
#
# ...

# %%
data.isnull().sum()
# Out:
# Country_code                     0
# Country                          0
# Total Library Size               0
# No. of TV Shows                  0
# No. of Movies                    0
# Cost Per Month - Basic ($)       0
# Cost Per Month - Standard ($)    0
# Cost Per Month - Premium ($)     0
# dtype: int64

# %% [markdown]
# ## Print the top and bottom records

# %%
data.head(8)
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
# 5           br     Brazil                4972             3162           1810
# 6           bg   Bulgaria                6797             4819           1978
# 7           ca     Canada                6239             4311           1928
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# ...

# %%
data.tail(10)
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 55           se          Sweden                4361             2973
# 56           ch     Switzerland                5506             3654
# 57           tw          Taiwan                5105             3134
# 58           th        Thailand                4948             2977
# 59           tr          Turkey                4639             2930
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 55           1388                       10.90                          14.20
# ...

# %% [markdown]
# ## Print the information of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country_code                   65 non-null     object
#  1   Country                        65 non-null     object
#  2   Total Library Size             65 non-null     int64
#  3   No. of TV Shows                65 non-null     int64
#  4   No. of Movies                  65 non-null     int64
#  5   Cost Per Month - Basic ($)     65 non-null     float64
#  6   Cost Per Month - Standard ($)  65 non-null     float64
#  7   Cost Per Month - Premium ($)   65 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 4.2+ KB

# %% [markdown]
# ## Drop the column

# %%
d=data.drop(['Country_code'],axis=1)
d
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0        Argentina                4760             3154           1606
# 1        Australia                6114             4050           2064
# 2          Austria                5640             3779           1861
# 3          Belgium                4990             3374           1616
# 4          Bolivia                4991             3155           1836
# ..             ...                 ...              ...            ...
# 60         Ukraine                5336             3261           2075
# 61  United Kingdom                6643             4551           2092
# 62   United States                5818             3826           1992
# 63         Uruguay                4989             3154           1835
# 64       Venezuela                4797             3154           1643
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
data
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %% [markdown]
# ## To extract the countries having no of shows same

# %%
shows=data.loc[(data['No. of TV Shows']==3154)]
shows
# Out:
#    Country_code    Country  Total Library Size  No. of TV Shows  \
# 0            ar  Argentina                4760             3154
# 21           gt  Guatemala                4767             3154
# 22           hn   Honduras                4989             3154
# 63           uy    Uruguay                4989             3154
# 64           ve  Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0            1606                        3.74                           6.30
# 21           1613                        7.99                          10.99
# 22           1835                        7.99                          10.99
# 63           1835                        8.99                          12.99
# 64           1643                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 0                           9.26
# 21                         13.99
# ...

# %% [markdown]
#  ##
#  Here we can see five countries have 3154 no. of shows

# %% [markdown]
# ## To extract the countries having same no of movies

# %%
movies=data.loc[(data['No. of Movies']==1835)]
movies
# Out:
#    Country_code   Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 9            co  Colombia                4991             3156           1835
# 22           hn  Honduras                4989             3154           1835
# 36           mx    Mexico                4993             3158           1835
# 63           uy   Uruguay                4989             3154           1835
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 9                         4.31                           6.86
# 22                        7.99                          10.99
# 36                        6.62                          10.43
# 63                        8.99                          12.99
#
#     Cost Per Month - Premium ($)
# 9                           9.93
# 22                         13.99
# 36                         14.24
# 63                         15.99

# %% [markdown]
# ##
# Here we can see four countries have 1835 no. of movies

# %% [markdown]
# ## To extract the countries having same basic cost

# %%
cost_basic=data.loc[(data['Cost Per Month - Basic ($)']==8.99)]
cost_basic
# Out:
#    Country_code        Country  Total Library Size  No. of TV Shows  \
# 10           cr     Costa Rica                4988             3152
# 62           us  United States                5818             3826
# 63           uy        Uruguay                4989             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 10           1836                        8.99                          12.99
# 62           1992                        8.99                          13.99
# 63           1835                        8.99                          12.99
#
#     Cost Per Month - Premium ($)
# 10                         15.99
# 62                         17.99
# 63                         15.99

# %% [markdown]
# ##
# Here we can see three countries have 8.99 basic cost

# %% [markdown]
# ## To extract the countries having same premium cost

# %%
cost_premium=data.loc[(data['Cost Per Month - Premium ($)']==20.32)]
cost_premium
# Out:
#    Country_code     Country  Total Library Size  No. of TV Shows  \
# 2            at     Austria                5640             3779
# 3            be     Belgium                4990             3374
# 17           fr      France                5445             3604
# 18           de     Germany                5668             3814
# 19           gi   Gibraltar                6167             4079
# 25           is     Iceland                6387             4426
# 28           ie     Ireland                6486             4515
# 30           it       Italy                5183             3545
# 49           sm  San Marino                2310             1937
# 54           es       Spain                5229             3536
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 2            1861                        9.03                          14.67
# 3            1616                       10.16                          15.24
# ...

# %% [markdown]
# ##
# Here we can see ten countries have 20.32 premium cost

# %% [markdown]
# ## To extract countries having same standard cost

# %%
cost_standard=data.loc[(data['Cost Per Month - Standard ($)']==14.67)]
cost_standard
# Out:
#    Country_code     Country  Total Library Size  No. of TV Shows  \
# 2            at     Austria                5640             3779
# 18           de     Germany                5668             3814
# 19           gi   Gibraltar                6167             4079
# 25           is     Iceland                6387             4426
# 28           ie     Ireland                6486             4515
# 30           it       Italy                5183             3545
# 49           sm  San Marino                2310             1937
# 54           es       Spain                5229             3536
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 2            1861                        9.03                          14.67
# 18           1854                        9.03                          14.67
# 19           2088                        9.03                          14.67
# ...

# %% [markdown]
# ##
# Here we can see eight countries have 14.67 standard cost

# %% [markdown]
# ## Print the statistical information

# %%
data.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# std            980.322633       723.010556     327.279748
# min           2274.000000      1675.000000     373.000000
# 25%           4948.000000      3154.000000    1628.000000
# 50%           5195.000000      3512.000000    1841.000000
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                      65.000000
# mean                     8.368462                      11.990000
# std                      1.937819                       2.863979
# min                      1.970000                       3.000000
# 25%                      7.990000                      10.710000
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# Country_code                     65
# Country                          65
# Total Library Size               62
# No. of TV Shows                  56
# No. of Movies                    56
# Cost Per Month - Basic ($)       35
# Cost Per Month - Standard ($)    39
# Cost Per Month - Premium ($)     40
# dtype: int64

# %%
data.corr()
# Out:
#                                Total Library Size  No. of TV Shows  \
# Total Library Size                       1.000000         0.971146
# No. of TV Shows                          0.971146         1.000000
# No. of Movies                            0.849957         0.699786
# Cost Per Month - Basic ($)              -0.062877        -0.003814
# Cost Per Month - Standard ($)           -0.055200         0.002285
# Cost Per Month - Premium ($)            -0.071521        -0.011100
#
#                                No. of Movies  Cost Per Month - Basic ($)  \
# Total Library Size                  0.849957                   -0.062877
# No. of TV Shows                     0.699786                   -0.003814
# No. of Movies                       1.000000                   -0.179913
# Cost Per Month - Basic ($)         -0.179913                    1.000000
# Cost Per Month - Standard ($)      -0.170391                    0.898535
# ...

# %%
data.cov()
# Out:
#                                Total Library Size  No. of TV Shows  \
# Total Library Size                  961032.465385    688332.347596
# No. of TV Shows                     688332.347596    522744.263462
# No. of Movies                       272700.117788    165588.084135
# Cost Per Month - Basic ($)            -119.446382        -5.343666
# Cost Per Month - Standard ($)         -154.980469         4.731250
# Cost Per Month - Premium ($)          -283.306546       -32.427519
#
#                                No. of Movies  Cost Per Month - Basic ($)  \
# Total Library Size             272700.117788                 -119.446382
# No. of TV Shows                165588.084135                   -5.343666
# No. of Movies                  107112.033654                 -114.102716
# Cost Per Month - Basic ($)       -114.102716                    3.755141
# Cost Per Month - Standard ($)    -159.711719                    4.986753
# ...

# %%
data.mean()
# Out:
# Total Library Size               5314.415385
# No. of TV Shows                  3518.953846
# No. of Movies                    1795.461538
# Cost Per Month - Basic ($)          8.368462
# Cost Per Month - Standard ($)      11.990000
# Cost Per Month - Premium ($)       15.612923
# dtype: float64

# %%
data.median()
# Out:
# Total Library Size               5195.00
# No. of TV Shows                  3512.00
# No. of Movies                    1841.00
# Cost Per Month - Basic ($)          8.99
# Cost Per Month - Standard ($)      11.49
# Cost Per Month - Premium ($)       14.45
# dtype: float64

# %%
data.mode()
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina              4797.0           3154.0
# 1            at       Australia              4989.0              NaN
# 2            au         Austria              4991.0              NaN
# 3            be         Belgium                 NaN              NaN
# 4            bg         Bolivia                 NaN              NaN
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                 NaN              NaN
# 61           us  United Kingdom                 NaN              NaN
# 62           uy   United States                 NaN              NaN
# 63           ve         Uruguay                 NaN              NaN
# 64           za       Venezuela                 NaN              NaN
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %% [markdown]
# ## Count the number of categories

# %%
data['Country'].value_counts()
# Out:
# Argentina        1
# Liechtenstein    1
# Malaysia         1
# Mexico           1
# Moldova          1
#                 ..
# Indonesia        1
# Ireland          1
# Israel           1
# Italy            1
# Venezuela        1
# Name: Country, Length: 65, dtype: int64

# %%
data['No. of Movies'].unique()
# Out:
# array([1606, 2064, 1861, 1616, 1836, 1810, 1978, 1928, 1838, 1835,  599,
#        2091, 1580, 1837, 1970, 1407, 1841, 1854, 2088, 1428, 1613, 1863,
#        2082, 1961, 2125, 1438, 1971, 2063, 1638, 1856, 1336, 1972, 2387,
#        1464, 1998, 1597, 2081, 1573, 1642, 1831, 2208, 1628, 1471, 2087,
#         373, 2194, 1980, 2050, 1693, 1388, 1852, 1709, 2075, 2092, 1992,
#        1643], dtype=int64)

# %%
d1=data.copy()
d1=d1.pivot_table('No. of TV Shows',columns='Country',aggfunc='sum')
d1
# Out:
# Country          Argentina  Australia  Austria  Belgium  Bolivia  Brazil  \
# No. of TV Shows       3154       4050     3779     3374     3155    3162
#
# Country          Bulgaria  Canada  Chile  Colombia  ...  Sweden  Switzerland  \
# No. of TV Shows      4819    4311   3156      3156  ...    2973         3654
#
# Country          Taiwan  Thailand  Turkey  Ukraine  United Kingdom  \
# No. of TV Shows    3134      2977    2930     3261            4551
#
# Country          United States  Uruguay  Venezuela
# No. of TV Shows           3826     3154       3154
#
# [1 rows x 65 columns]

# %%
d3=data.copy()
d3
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
d3['Cost Per Month - Basic ($)']=data['Cost Per Month - Basic ($)']*data['No. of Movies']
d3['Cost Per Month - Basic ($)']
# Out:
# 0      6006.44
# 1     16181.76
# 2     16804.83
# 3     16418.56
# 4     14669.64
#         ...
# 60    11703.00
# 61    16547.72
# 62    17908.08
# 63    16496.65
# 64    13127.57
# Name: Cost Per Month - Basic ($), Length: 65, dtype: float64

# %%
d3['Cost Per Month - Premium ($)']=data['Cost Per Month - Premium ($)']*data['No. of TV Shows']
d3['Cost Per Month - Premium ($)']
# Out:
# 0     29206.04
# 1     66379.50
# 2     76789.28
# 3     68559.68
# 4     44138.45
#         ...
# 60    36816.69
# 61    84102.48
# 62    68829.74
# 63    50432.46
# 64    44124.46
# Name: Cost Per Month - Premium ($), Length: 65, dtype: float64

# %% [markdown]
# ## Grouping based on country and premium cost

# %%
d3=data.copy()
d3
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
d3=d3.groupby(['Country'])['Cost Per Month - Premium ($)'].sum()
d3=pd.DataFrame(d3)
d3
# Out:
#                 Cost Per Month - Premium ($)
# Country
# Argentina                               9.26
# Australia                              16.39
# Austria                                20.32
# Belgium                                20.32
# Bolivia                                13.99
# ...                                      ...
# Ukraine                                11.29
# United Kingdom                         18.48
# United States                          17.99
# Uruguay                                15.99
# Venezuela                              13.99
#
# [65 rows x 1 columns]

# %% [markdown]
# ## Data Visualization

# %%
n=d3.head(10)
n
# Out:
#            Cost Per Month - Premium ($)
# Country
# Argentina                          9.26
# Australia                         16.39
# Austria                           20.32
# Belgium                           20.32
# Bolivia                           13.99
# Brazil                             9.96
# Bulgaria                          13.54
# Canada                            15.03
# Chile                             12.74
# Colombia                           9.93

# %%
x=n
plt.figure(figsize=(10,5))
plt.title('Netflix Subscription')
plt.xlabel('Country')
plt.ylabel('Cost Per Month - Premium ($)')

plt.plot(x,marker='o',color='red')
plt.show()

# %% [markdown]
# ##
# Here we can see Austria and Belgium has the highest premium cost for subscription

# %% [markdown]
# ## Grouping based on country and no.of tv shows

# %%
d3=data.copy()
d3
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
d3=d3.groupby(['Country'])['No. of TV Shows'].sum()
d3=pd.DataFrame(d3)
d3
# Out:
#                 No. of TV Shows
# Country
# Argentina                  3154
# Australia                  4050
# Austria                    3779
# Belgium                    3374
# Bolivia                    3155
# ...                         ...
# Ukraine                    3261
# United Kingdom             4551
# United States              3826
# Uruguay                    3154
# Venezuela                  3154
#
# [65 rows x 1 columns]

# %%
a=d3.tail(10)
a
# Out:
#                 No. of TV Shows
# Country
# Sweden                     2973
# Switzerland                3654
# Taiwan                     3134
# Thailand                   2977
# Turkey                     2930
# Ukraine                    3261
# United Kingdom             4551
# United States              3826
# Uruguay                    3154
# Venezuela                  3154

# %%
x=a
font1={'color':'blue','size':20}
font2={'color':'red','size':15}

plt.figure(figsize=(10,5))
plt.title('Netflix shows',fontdict=font1)
plt.xlabel('Country',fontdict=font2)
plt.ylabel('No. of TV Shows',fontdict=font2)

plt.plot(x,marker='*',ms=15)
plt.show()

# %% [markdown]
# ##
# Here we can see United Kingdom  has the highest no of Tv Shows and Sweden has the lowest no of tv shows

# %% [markdown]
# ## Grouping by country and standard cost

# %%
d3=data.copy()
d3
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
d3=d3.groupby(['Country'])['Cost Per Month - Standard ($)'].sum()
d3=pd.DataFrame(d3)
d3
# Out:
#                 Cost Per Month - Standard ($)
# Country
# Argentina                                6.30
# Australia                               12.12
# Austria                                 14.67
# Belgium                                 15.24
# Bolivia                                 10.99
# ...                                       ...
# Ukraine                                  8.46
# United Kingdom                          13.20
# United States                           13.99
# Uruguay                                 12.99
# Venezuela                               10.99
#
# [65 rows x 1 columns]

# %%
m=d3.tail(10)
m
# Out:
#                 Cost Per Month - Standard ($)
# Country
# Sweden                                  14.20
# Switzerland                             20.46
# Taiwan                                  11.90
# Thailand                                10.43
# Turkey                                   3.00
# Ukraine                                  8.46
# United Kingdom                          13.20
# United States                           13.99
# Uruguay                                 12.99
# Venezuela                               10.99

# %%
x=m
font1={'color':'green','size':20}
font2={'color':'blue','size':15}

plt.figure(figsize=(10,5))
plt.title('Netflix subscription',fontdict=font1)
plt.xlabel('Country',fontdict=font2)
plt.ylabel('Cost Per Month - Standard ($)',fontdict=font2)

plt.plot(x,marker='*',ms=15,mec='k',mfc='c')
plt.show()

# %% [markdown]
# ##
# Here we can see Switzerland has the highest and Turkey has the lowest standard cost for subscription

# %%
p=d3.head(10)
p
# Out:
#            Cost Per Month - Standard ($)
# Country
# Argentina                           6.30
# Australia                          12.12
# Austria                            14.67
# Belgium                            15.24
# Bolivia                            10.99
# Brazil                              7.11
# Bulgaria                           11.29
# Canada                             11.87
# Chile                               9.91
# Colombia                            6.86

# %% [markdown]
# ## Display multiple plots

# %%
from matplotlib import style
style.use('ggplot')
x=p

plt.figure(figsize=(15,5))
plt.subplot(1,2,2)
plt.plot(x,)
plt.title('Standard cost')

x=n
plt.subplot(1,2,1)
plt.plot(x)
plt.title('Premium cost')

plt.suptitle('Netflix subscription')
plt.show()

# %% [markdown]
# ##
# Here we can see Belgium has both premium and standard cost high

# %%
sn=data.head(6)
sns.scatterplot(x='Country',y='Cost Per Month - Standard ($)',data=sn)
plt.show()

# %%
plt.figure(figsize=(10,4))
cs=data.head(10)
sns.barplot(x='Country',y='No. of TV Shows',data=cs)


plt.show()

# %%
Basic=sns.lineplot(x='Cost Per Month - Basic ($)',y='Country',data=cs)
Standard=sns.lineplot(x='Cost Per Month - Standard ($)',y='Country',data=cs)
plt.title("Subscription fee")  
plt.xlabel("Cost per Month")  
plt.ylabel("Country")
plt.legend(["Basic","Standard"])
plt.show()

# %% [markdown]
# ##
# Here we can see Argentina has the basic and standard cost high

# %%
d3=data.copy()
d3
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
e=d3.head(8)
e
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
# 5           br     Brazil                4972             3162           1810
# 6           bg   Bulgaria                6797             4819           1978
# 7           ca     Canada                6239             4311           1928
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# ...

# %% [markdown]
# ## Comparison of two datas using Barplot

# %%
e.groupby('Country')[['Cost Per Month - Basic ($)','Cost Per Month - Standard ($)','Cost Per Month - Premium ($)']].sum().plot.bar(color=['blue','red','green'],figsize=(8,5))
plt.ylabel('Movies and Shows')
plt.show()

# %% [markdown]
# ##
# Here we can see standard cost is high for Austria and Belgium,while Argentina and Brazil has the less cost.

# %%
data.groupby('Country')[['Cost Per Month - Basic ($)','Cost Per Month - Standard ($)','Cost Per Month - Premium ($)']].sum().plot.bar(color=['blue','red','green'],figsize=(15,5))
plt.ylabel('Movies and Shows')
plt.show()

# %% [markdown]
# ##
# Here we can see Liechtenstein and Switzerland has the high subscription fee on Netflix.

# %%
data.groupby('Country')[['No. of TV Shows','No. of Movies']].sum().plot.bar(color=['green','yellow'],figsize=(15,5))
plt.ylabel('Movies and Shows')
plt.show()

# %% [markdown]
# ##
# Here we can see no of tv shows is higher than no of movies that are available in Netflix.

# %% [markdown]
# ## Visualization using pieplot

# %%
plt.title('Country',fontsize=20)
e['Country'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,explode=(0,0,0,0.2,0,0,0,0))
plt.show()

# %%
plt.title('No. of Movies',fontsize=20)
e['No. of Movies'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,explode=(0,0,0.2,0,0,0,0,0))
plt.show()

# %% [markdown]
# ## Conclusion
#
# The analysis of Netflix subscription fee depicts among the different countries. Czechila and Slovakia has the highest number of TV shows while countries like San Marino and Croatia has the lowest number of Movies available on Netflix.
# Countries like Liechtenstein and Switzerland has the high subscription fee, while Turkey has the lowest subscription fee.
